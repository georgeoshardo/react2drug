# %% [markdown]
# # HackMed 21: FDA Drug Shortage Web Scraper
# Start: 24.04.2021 | author Camillo Moschner (cm967)
#
# Source data: https://www.accessdata.fda.gov/scripts/drugshortages/default.cfm

# %% [markdown]
# ## Import statements

# %%
import numpy as np
import pandas as pd
import re
import pickle

# %%
import requests
from bs4 import BeautifulSoup
from pandas.io.html import read_html

# %%
from HackMed21_0_helper import find_name
from HackMed21_0_helper import find_status
from HackMed21_0_helper import find_CAS_number_and_ChEBI

# %% [markdown]
# Additional dependencies:

# %%
# !pip install lxml
# !pip install html5lib

# %% [markdown]
# ## Wikipedia Explorer

# %%
wikipedia_link = "https://en.wikipedia.org/wiki/"
drug_name = "Acetazolamide" # taken directly from the FDA Drug Shortage website
drug_wikipedia_link = wikipedia_link+drug_name
drug_page = requests.get(drug_wikipedia_link)
drug_soup = BeautifulSoup(drug_page.content, 'html.parser')
p=drug_soup.find(id='mw-content-text')

# %% [markdown]
# Explore Wikipedia's molecule infobox to identify useful parameters to scrape:

# %%
infoboxes = read_html(drug_wikipedia_link, index_col=0, attrs={"class":"infobox"})
pd.set_option('display.max_columns', None)
infoboxes[0].T
# Out:
# 0  NaN  NaN  Clinical data              Trade names AHFS/Drugs.com  \
# 1  NaN  NaN  Clinical data  Diamox, Diacarb, others      Monograph
#
# 0 Pregnancycategory  Routes ofadministration       ATC code  Legal status  \
# 1            AU: B3  by mouth or intravenous  S01EC01 (WHO)  Legal status
#
# 0                                       Legal status  Pharmacokinetic data  \
# 1  AU: S4 (Prescription only) CA: ℞-only UK: POM ...  Pharmacokinetic data
#
# 0 Protein binding Metabolism Elimination half-life       Excretion  \
# 1       70–90%[1]    None[1]          2–4 hours[1]  Urine (90%)[1]
#
# 0  Identifiers IUPAC name N-(5-Sulfamoyl-1,3,4-thiadiazol-2-yl)acetamide  \
# 1  Identifiers  IUPAC name N-(5-Sulfamoyl-1,3,4-thiadiazol-2-y...
#
# 0 CAS Number PubChem CID IUPHAR/BPS DrugBank ChemSpider        UNII    KEGG  \
# 1    59-66-5        1986       6792  DB00819       1909  O3FX965V0I  D00218
#
# 0        ChEBI    ChEMBL            PDB ligand CompTox Dashboard (EPA)  \
# 1  CHEBI:27690  ChEMBL20  AZM (PDBe, RCSB PDB)           DTXSID7022544
#
# 0 ECHA InfoCard  Chemical and physical data     Formula      Molar mass  \
# 1   100.000.400  Chemical and physical data  C4H6N4O3S2  222.24 g·mol−1
#
# 0   3D model (JSmol)                  Melting point  \
# 1  Interactive image  258 to 259 °C (496 to 498 °F)
#
# 0  SMILES NS(=O)(=O)c1nnc(s1)NC(=O)C  \
# 1  SMILES NS(=O)(=O)c1nnc(s1)NC(=O)C
#
# 0 InChI InChI=1S/C4H6N4O3S2/c1-2(9)6-3-7-8-4(12-3)13(5,10)11/h1H3,(H2,5,10,11)(H,6,7,9) Key:BZKPWHYZMXOIDC-UHFFFAOYSA-N  \
# 1  InChI InChI=1S/C4H6N4O3S2/c1-2(9)6-3-7-8-4(12-...
#
# 0 .mw-parser-output .nobold{font-weight:normal} (verify)
# 1  .mw-parser-output .nobold{font-weight:normal} ...

# %% [markdown]
# Retrieval example (for full functions see "HackMed21_helper.py" file).

# %%
infoboxes[0].xs(u'ChEBI').values[0]
# Out:
# 'CHEBI:27690'

# %% [markdown]
# ## FDA & Wikipedia Scraper

# %% [markdown]
# Load website you want to scrape as a request instance

# %%
URL = 'https://www.accessdata.fda.gov/scripts/drugshortages/default.cfm'
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# Find the table of drugs exhibiting a shortage using the html id for content:

# %%
results = soup.find(id="cont").find('tbody')

# %% [markdown]
# Create a dictionary in which each key:value pair represents a Table Data Cell element:

# %%
table_list = results.find_all('tr')
print('The FDA Drug Shortage list has {:} entries.'.format(len(table_list)))
# Out:
# The FDA Drug Shortage list has 161 entries.

# %% [markdown]
# ### Main Parser
# ...definitely "over-the-top, over-engineered, and held together with Sellotape and bits of string…" :P
#
# Parse table_list (a bs4.element.ResultSet) to retrieve the drug name and its status:

# %%
drug_par=[]
for row in table_list:
    info = []
    # retrieve the drug name:
    unparsed_name_str = row.find_all('a')[1]['title']
    name_str = find_name(unparsed_name_str)
    if 'Parathyroid' in name_str:
        abbr_name = 'Parathyroid Hormone'
    if 'Injection' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Capsules' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Tablets' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Multi-Vitamin' in name_str:
        abbr_name = 'Multivitamin'
    elif '(' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Ointment' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Solution' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Strips' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Histreline' in name_str:
        abbr_name = 'Histrelin'
    elif 'Implant' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Suspension' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Emulsion' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Aerosol' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'System' in name_str:
        abbr_name = name_str.split(' ')[0]
    elif 'Sterile Water' in name_str:
        abbr_name = 'Water for injection'
    else:
        abbr_name = name_str 
    info.append(name_str)
    info.append(abbr_name)
    # retrieve the status:
    unparsed_status_str = str(row.find('strong'))
    status_str = find_status(unparsed_status_str)
    info.append(status_str)
    # retrieve FDA accessdata hyperlink:
    base_link = "https://www.accessdata.fda.gov/scripts/drugshortages/"
    specific_link=row.find_all('a')[1]['href']
    info.append(base_link+specific_link)
    # scrape Wikipedia for CAS number:
    wiki_info = find_CAS_number_and_ChEBI(abbr_name)
    CAS_number = wiki_info[0]
    ChEBI = wiki_info[1]
    info.append(CAS_number)
    info.append(ChEBI)

    drug_par.append(info)
# Out:
# https://en.wikipedia.org/wiki/Acetazolamide
# https://en.wikipedia.org/wiki/Amifostine
# https://en.wikipedia.org/wiki/Amino_Acids
# https://en.wikipedia.org/wiki/Aminophylline
# https://en.wikipedia.org/wiki/Amoxapine
# https://en.wikipedia.org/wiki/Amphetamine
# https://en.wikipedia.org/wiki/Sildenafil
# https://en.wikipedia.org/wiki/Sincalide
# https://en.wikipedia.org/wiki/Sodium
# https://en.wikipedia.org/wiki/Sodium
# https://en.wikipedia.org/wiki/Sodium
# https://en.wikipedia.org/wiki/Sodium
# https://en.wikipedia.org/wiki/Sodium
# https://en.wikipedia.org/wiki/Water_for_injection
# https://en.wikipedia.org/wiki/Succimer
# https://en.wikipedia.org/wiki/Sulfasalazine
# https://en.wikipedia.org/wiki/Tacrolimus
# https://en.wikipedia.org/wiki/Technetium
# https://en.wikipedia.org/wiki/Teprotumumab-trbw
# https://en.wikipedia.org/wiki/Thiothixene
# https://en.wikipedia.org/wiki/Timolol
# https://en.wikipedia.org/wiki/Timolol
# https://en.wikipedia.org/wiki/Timolol
# https://en.wikipedia.org/wiki/Tobramycin
# https://en.wikipedia.org/wiki/Triamcinolone
# https://en.wikipedia.org/wiki/Trifluridine
# https://en.wikipedia.org/wiki/Trimethobenzamide
# https://en.wikipedia.org/wiki/Valproate
# https://en.wikipedia.org/wiki/Vecuronium
# https://en.wikipedia.org/wiki/Zinc
# https://en.wikipedia.org/wiki/Zolpidem

# %% [markdown]
# Create a Pandas DataFrame combining all the the web scraped information into one easily-accessible data structure.

# %%
df = pd.DataFrame(drug_par, columns=['full_drug_name','name','status','link','CAS_number','ChEBI'])

# %% [markdown]
# Check all the drugs that created 'N/A' values (probably due to some unwanted code behaviour) to check how to optimize the code.

# %%
df.loc[df['ChEBI']=='N/A']
# Out:
#                                         full_drug_name                 name  \
# 2                                          Amino Acids          Amino Acids
# 7         Asparaginase Erwinia Chrysanthemi (Erwinaze)         Asparaginase
# 13   Belatacept (Nulojix) Lyophilized Powder for In...           Belatacept
# 18                     Calcium Chloride Injection, USP              Calcium
# 19                Calcium Disodium Versenate Injection              Calcium
# 20                         Calcium Gluconate Injection              Calcium
# 21                          Capreomycin Injection, USP          Capreomycin
# 24                         Cefotaxime Sodium Injection           Cefotaxime
# 28      Ceftolozane and Tazobactam (Zerbaxa) Injection          Ceftolozane
# 32   Continuous Renal Replacement Therapy (CRRT) So...           Continuous
# 38          Desmopressin Acetate (Stimate) Nasal Spray         Desmopressin
# 45         Difluprednate (Durezol) Ophthalmic Emulsion        Difluprednate
# 47              Dimercaprol (Bal in Oil) Injection USP          Dimercaprol
# 51                    Dopamine Hydrochloride Injection             Dopamine
# 61                                 Etomidate Injection            Etomidate
# 73                    Guanfacine Hydrochloride Tablets           Guanfacine
# 75   Heparin Sodium and Sodium Chloride 0.9% Injection              Heparin
# 76                          Histreline Acetate Implant            Histrelin
# 80                          Hydroxocobalamin Injection     Hydroxocobalamin
# 90                     Letermovir (Prevymis) Injection           Letermovir
# 91   Leucovorin Calcium Lyophilized Powder for Inje...           Leucovorin
# 92                        Leuprolide Acetate Injection           Leuprolide
# 98                               Lithium Oral Solution              Lithium
# 99                            Lorazepam Injection, USP            Lorazepam
# 102                                 Methyldopa Tablets           Methyldopa
# 107                                Misoprostol Tablets          Misoprostol
# 109       Multi-Vitamin Infusion (Adult and Pediatric)         Multivitamin
# 113                Ondansetron Hydrochloride Injection          Ondansetron
# 116            Parathyroid Hormone (Natpara) Injection          Parathyroid
# 121                   Potassium Acetate Injection, USP            Potassium
# 127                   Protamine Sulfate Injection, USP            Protamine
# 130                       Rocuronium Bromide Injection           Rocuronium
# 137  Sincalide (Kinevac) Lyophilized Powder for Inj...            Sincalide
# 138                      Sodium Acetate Injection, USP               Sodium
# 139                  Sodium Bicarbonate Injection, USP               Sodium
# 140                Sodium Chloride 0.9% Injection Bags               Sodium
# 141                    Sodium Chloride 23.4% Injection               Sodium
# 142  Sodium Chloride Injection USP, 0.9% Vials and ...               Sodium
# 143                                      Sterile Water  Water for injection
# 144                         Succimer (Chemet) Capsules             Succimer
# 147         Technetium Tc99m Succimer Injection (DMSA)           Technetium
# 148                                  Teprotumumab-trbw    Teprotumumab-trbw
# 149                               Thiothixene Capsules          Thiothixene
# 158                   Vecuronium Bromide for Injection           Vecuronium
# 159                              Zinc Acetate Capsules                 Zinc
#
#                     status                                               link  \
# 2    Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 7    Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 13   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 18                Resolved  https://www.accessdata.fda.gov/scripts/drugsho...
# 19   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 20   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 21   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 24   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 28   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 32   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 38   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 45                Resolved  https://www.accessdata.fda.gov/scripts/drugsho...
# 47   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 51   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 61                Resolved  https://www.accessdata.fda.gov/scripts/drugsho...
# 73   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 75   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 76   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 80   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 90   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 91   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 92   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 98   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 99   Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 102  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 107  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 109  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 113  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 116  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 121  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 127  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 130               Resolved  https://www.accessdata.fda.gov/scripts/drugsho...
# 137  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 138  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 139  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 140               Resolved  https://www.accessdata.fda.gov/scripts/drugsho...
# 141  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 142  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 143               Resolved  https://www.accessdata.fda.gov/scripts/drugsho...
# 144  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 147  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 148  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 149  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 158  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
# 159  Currently in Shortage  https://www.accessdata.fda.gov/scripts/drugsho...
#
#     CAS_number ChEBI
# 2          N/A   N/A
# 7          N/A   N/A
# 13         N/A   N/A
# 18         N/A   N/A
# 19         N/A   N/A
# 20         N/A   N/A
# 21         N/A   N/A
# 24         N/A   N/A
# 28         N/A   N/A
# 32         N/A   N/A
# 38         N/A   N/A
# 45         N/A   N/A
# 47         N/A   N/A
# 51         N/A   N/A
# 61         N/A   N/A
# 73         N/A   N/A
# 75         N/A   N/A
# 76         N/A   N/A
# 80         N/A   N/A
# 90         N/A   N/A
# 91         N/A   N/A
# 92         N/A   N/A
# 98         N/A   N/A
# 99         N/A   N/A
# 102        N/A   N/A
# 107        N/A   N/A
# 109        N/A   N/A
# 113        N/A   N/A
# 116        N/A   N/A
# 121        N/A   N/A
# 127        N/A   N/A
# 130        N/A   N/A
# 137        N/A   N/A
# 138        N/A   N/A
# 139        N/A   N/A
# 140        N/A   N/A
# 141        N/A   N/A
# 142        N/A   N/A
# 143        N/A   N/A
# 144        N/A   N/A
# 147        N/A   N/A
# 148        N/A   N/A
# 149        N/A   N/A
# 158        N/A   N/A
# 159        N/A   N/A

# %% [markdown]
# ## Data Backup

# %%
pickle.dump( df, open( "/Users/camillomoschner/Documents/GitHub/react2drug/drug_shortages.p", "wb" ) )
